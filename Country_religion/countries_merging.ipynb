# %%
import pandas as pd
import glob
import csv
import matplotlib.pyplot as plt
import numpy as np
from numpy import *

# %%
religion_df = pd.read_csv("religions_country.csv")
un_regions_df  = pd.read_csv("un-regional-groups.csv")

# %%
religion_df.head(10)
# Out:
#                Country               Religion
# 0          Afghanistan                  Islam
# 1              Albania                  Islam
# 2              Algeria                  Islam
# 3              Andorra        Roman Catholic
# 4               Angola  indigenous beliefs
# 5  Antigua and Barbuda               Anglican
# 6            Argentina      Roman Catholic
# 7              Armenia  Armenian Apostolic
# 8            Australia      Roman Catholic
# 9              Austria      Roman Catholic

# %%
un_regions_df.head(10)
# Out:
#   Code                   Country         Region
# 0  DZA                   Algeria  African Group
# 1  AGO                    Angola  African Group
# 2  BEN                     Benin  African Group
# 3  BWA                  Botswana  African Group
# 4  BFA              Burkina Faso  African Group
# 5  BDI                   Burundi  African Group
# 6  CPV                Cabo Verde  African Group
# 7  CMR                  Cameroon  African Group
# 8  CAF  Central African Republic  African Group
# 9  TCD                      Chad  African Group

# %%
countries_merged = pd.merge(un_regions_df, religion_df)

# %%
countries_merged.head(10)
# Out:
#   Code                   Country         Region               Religion
# 0  DZA                   Algeria  African Group                  Islam
# 1  AGO                    Angola  African Group  indigenous beliefs
# 2  BEN                     Benin  African Group  indigenous beliefs
# 3  BWA                  Botswana  African Group           Christian
# 4  BFA              Burkina Faso  African Group               Islam
# 5  BDI                   Burundi  African Group      Roman Catholic
# 6  CMR                  Cameroon  African Group  indigenous beliefs
# 7  CAF  Central African Republic  African Group  indigenous beliefs
# 8  TCD                      Chad  African Group               Islam
# 9  COM                   Comoros  African Group                  Islam

# %%
countries_merged.to_csv("merged_countries.csv")
