# %%
# import libraries
from preprocess_data import *
import os
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import folium
from folium import plugins
from IPython.core.display import display, HTML

# %%
process_country_name(projectdata_PATH + "Human_Development_Index.csv", projectdata_PATH + "Human_Development_Index_namecleaned.csv", 0)

# %%
hdi = pd.read_csv(projectdata_PATH + 'Human_Development_Index_namecleaned.csv', sep=',')

# %%
old_hdi = pd.read_csv(projectdata_PATH + 'Human_Development_Index.csv', sep=',')

# %%
old_hdi
# Out:
#          Country HDI_2016
# 0    Afghanistan    0.494
# 1        Albania    0.782
# 2        Algeria    0.753
# 3        Andorra    0.856
# 4         Angola    0.577
# ..           ...      ...
# 190       Monaco       ..
# 191        Nauru       ..
# 192   San Marino       ..
# 193      Somalia       ..
# 194       Tuvalu       ..
#
# [195 rows x 2 columns]

# %%
hdi
# Out:
#          Country HDI_2016
# 0    Afghanistan    0.494
# 1        Albania    0.782
# 2        Algeria    0.753
# 3        Andorra    0.856
# 4         Angola    0.577
# ..           ...      ...
# 190       Monaco       ..
# 191        Nauru       ..
# 192    Sanmarino       ..
# 193      Somalia       ..
# 194       Tuvalu       ..
#
# [195 rows x 2 columns]

# %%
process_country_name(projectdata_PATH + "Prison_population.csv", projectdata_PATH + "Prison_population_namecleaned.csv", 0)

# %%
prison = pd.read_csv(projectdata_PATH + 'Prison_population_namecleaned.csv', sep=',')

# %%
prison
# Out:
#                 Country Median age (years)
# 0           Afghanistan               17.3
# 1               Albania               36.2
# 2               Algeria               27.5
# 3                Angola               16.4
# 4     Antiguaandbarbuda               30.7
# ..                  ...                ...
# 190               Nauru                 ..
# 191               Palau                 ..
# 192  Saintkittsandnevis                 ..
# 193           Sanmarino                 ..
# 194              Tuvalu                 ..
#
# [195 rows x 2 columns]

# %%
process_country_name(projectdata_PATH + "Unemployment.csv", projectdata_PATH + "Unemployment_namecleaned.csv", 0)

# %%
un = pd.read_csv(projectdata_PATH + 'Unemployment_namecleaned.csv', sep=',')

# %%
un
# Out:
#                 Country Unemployment, total (% of labour force)
# 0           Afghanistan                                     8.8
# 1               Albania                                    15.2
# 2               Algeria                                    10.2
# 3                Angola                                     7.7
# 4             Argentina                                     8.4
# ..                  ...                                     ...
# 190               Palau                                      ..
# 191  Saintkittsandnevis                                      ..
# 192           Sanmarino                                      ..
# 193          Seychelles                                      ..
# 194              Tuvalu                                      ..
#
# [195 rows x 2 columns]

# %%
process_country_name(projectdata_PATH + "Median_age.csv", projectdata_PATH + "Median_age_namecleaned.csv", 0)

# %%
median = pd.read_csv(projectdata_PATH + 'Median_age_namecleaned.csv', sep=',')

# %%
median
# Out:
#                 Country Median age (years)
# 0           Afghanistan               17.3
# 1               Albania               36.2
# 2               Algeria               27.5
# 3                Angola               16.4
# 4     Antiguaandbarbuda               30.7
# ..                  ...                ...
# 190               Nauru                 ..
# 191               Palau                 ..
# 192  Saintkittsandnevis                 ..
# 193           Sanmarino                 ..
# 194              Tuvalu                 ..
#
# [195 rows x 2 columns]

# %%
process_country_name(projectdata_PATH + "GDP.csv", projectdata_PATH + "GDP_namecleaned.csv", 0)

# %%
gdp = pd.read_csv(projectdata_PATH + 'GDP_namecleaned.csv', sep=',')

# %%
gdp
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                             Angola
# 4                  Antiguaandbarbuda
# ..                               ...
# 190  Korea(democraticpeople'srep.of)
# 191                    Liechtenstein
# 192                           Monaco
# 193                          Somalia
# 194               Syrianarabrepublic
#
#     Gross domestic product (GDP) per capita (2011 PPP $)
# 0                                                 1803
# 1                                                11356
# 2                                                13921
# 3                                                 5972
# 4                                                21013
# ..                                                 ...
# 190                                                 ..
# 191                                                 ..
# ...
